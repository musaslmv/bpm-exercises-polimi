# %%
import pandas as pd
import numpy as np
import os

# %%
df_small = pd.read_csv(os.getcwd() + '/Small.csv')

# %%
df_small = df_small.rename(columns={"Case ID": "caseid", "Activity": "activity", "Complete Timestamp": "ts"})

# %%
event_log = df_small[["caseid","activity","ts"]]

# %%
# Convert 'ts' to datetime format
event_log['ts'] = pd.to_datetime(event_log['ts'])

# Group by 'caseid' and aggregate events into a list ordered by timestamp
CaseidList = event_log.groupby('caseid').agg({
    'ts': lambda x: x.sort_values().tolist(),
    'activity': lambda x: x.tolist()
}).reset_index()

# %%
# Calculate duration and event_number
CaseidList['duration'] = CaseidList['ts'].apply(lambda x: max(x) - min(x))
CaseidList['event_number'] = CaseidList['activity'].apply(len)

# %%
CaseidList
# Out:
#           caseid                                                 ts  \
# 0         case_0  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 1         case_1  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 2        case_10  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 3       case_100  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 4      case_1000  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# ...          ...                                                ...
# 12495  case_9995  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12496  case_9996  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12497  case_9997  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12498  case_9998  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12499  case_9999  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
#
#                                                 activity        duration  \
# 0      [Activity A, Activity B, Activity C, Activity ... 0 days 06:00:00
# 1      [Activity A, Activity B, Activity C, Activity ... 0 days 08:00:00
# 2      [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 3      [Activity A, Activity B, Activity C, Activity ... 0 days 06:00:00
# 4      [Activity A, Activity B, Activity C, Activity ... 0 days 06:00:00
# ...                                                  ...             ...
# 12495  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 12496  [Activity A, Activity B, Activity C, Activity ... 0 days 06:00:00
# 12497  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 12498  [Activity A, Activity B, Activity C, Activity ... 0 days 06:00:00
# 12499  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
#
#        event_number
# 0                 7
# 1                 9
# 2                10
# 3                 7
# 4                 7
# ...             ...
# 12495            10
# 12496             7
# 12497            10
# 12498             7
# 12499            10
#
# [12500 rows x 5 columns]

# %%
# Find the longest case by duration
longest_case = CaseidList.loc[CaseidList['duration'].idxmax()]

# Find the shortest case by duration
shortest_case = CaseidList.loc[CaseidList['duration'].idxmin()]

# %%
longest_case
# Out:
# caseid                                                    case_10
# ts              [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# activity        [Activity A, Activity B, Activity C, Activity ...
# duration                                          0 days 09:00:00
# event_number                                                   10
# Name: 2, dtype: object

# %%
shortest_case
# Out:
# caseid                                                     case_0
# ts              [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# activity        [Activity A, Activity B, Activity C, Activity ...
# duration                                          0 days 06:00:00
# event_number                                                    7
# Name: 0, dtype: object

# %%
longest_case_by_nof_events = CaseidList[CaseidList['event_number'] == CaseidList['event_number'].max()]

# %%
longest_case_by_nof_events
# Out:
#            caseid                                                 ts  \
# 2         case_10  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 5      case_10000  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 7      case_10002  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 8      case_10003  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 9      case_10004  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# ...           ...                                                ...
# 12492   case_9992  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12493   case_9993  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12495   case_9995  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12497   case_9997  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
# 12499   case_9999  [1970-01-01 09:00:00, 1970-01-01 10:00:00, 197...
#
#                                                 activity        duration  \
# 2      [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 5      [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 7      [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 8      [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 9      [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# ...                                                  ...             ...
# 12492  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 12493  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 12495  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 12497  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
# 12499  [Activity A, Activity B, Activity C, Activity ... 0 days 09:00:00
#
#        event_number
# 2                10
# 5                10
# 7                10
# 8                10
# 9                10
# ...             ...
# 12492            10
# 12493            10
# 12495            10
# 12497            10
# 12499            10
#
# [7244 rows x 5 columns]
